# %%
import docx2txt
from docx import Document
import re
from IPython.display import display, clear_output
from itertools import product
from collections import OrderedDict
from collections import namedtuple
import pandas as pd

filepath_en  = './dataset/dataset/September_english_2020.docx'
filepath_fr = './dataset/dataset/September_french_2020.docx'

# %%
filenames = ['December', 'February', 'January', 'October', 'September']
filepath = './dataset/dataset/'
doc_en = Document(filepath_en)
doc_fr = Document(filepath_fr)
# document = Document()

# %%
def examine_doc(doc, show_temp=False):
    vocabs = []
    vocabs_ = []
    temp = []
    
    for paragraph in doc.paragraphs:
        if paragraph.text == '':
            vocabs.append(len(temp))
            vocabs_.append(temp)
            if show_temp: print(temp)
            temp = []
            continue
        temp.append(paragraph.text)
        
    vocabs = [paragraph for paragraph in vocabs if paragraph != 0]
    vocabs_ = [paragraph for paragraph in vocabs_ if len(paragraph) != 0]
    return vocabs,vocabs_

def process_doc(doc, show_temp=False):
    vocabs = []
    
    for paragraph in doc.paragraphs:
        if paragraph.text == '':
            if show_temp: print(paragraph.text)
            continue
        vocabs.append(str(paragraph.text).lower())
        
    vocabs = [paragraph for paragraph in vocabs if len(paragraph) != 0]
    return vocabs

def compare_docs(vocab_en, vocab_fr):
    results = []
    for idx, num in enumerate(vocab_en):
        temp = OrderedDict()
        temp['Index'] = idx
        temp["English"] = num
        temp['French'] = vocab_fr[idx]
        temp['Status'] = num == vocab_fr[idx]

        results.append(temp)

    df = pd.DataFrame.from_dict(results, orient='columns')
    clear_output(wait=True)
    display(df)

# %%
vocab_en_,_vocab_en_ = examine_doc(doc_en)
vocab_fr_,_vocab_fr_ = examine_doc(doc_fr)
compare_docs(vocab_en_, vocab_fr_)
# Out:
#     Index  English  French  Status
# 0       0        9       9    True
# 1       1        8       8    True
# 2       2        9       9    True
# 3       3        9       9    True
# 4       4        9       9    True
# 5       5        8       8    True
# 6       6       10      10    True
# 7       7       10      10    True
# 8       8        8       8    True
# 9       9        9       9    True
# 10     10        8       8    True
# 11     11        8       8    True
# 12     12       10      10    True
# 13     13        8       8    True
# 14     14        9       9    True
# 15     15        9       9    True
# 16     16        9       9    True
# 17     17        9       9    True
# 18     18        9       9    True
# 19     19        7       7    True
# 20     20        9       9    True
# 21     21        9       9    True
# 22     22        7       7    True
# 23     23        8       8    True
# 24     24       10      10    True
# 25     25        9       9    True
# 26     26        9       9    True
# 27     27       10      10    True
# 28     28        8       8    True

# %%
ref = 10
print(_vocab_en_[ref][0])
print(_vocab_fr_[ref][0])
# Out:
# MANIFESTING HIS VIRTUES AND EXCELLENCE
# MANIFESTEZ SES VERTUS ET SON EXCELLENCE

# %%
vocab_en = process_doc(doc_en)
vocab_fr = process_doc(doc_fr)
print(len(vocab_en), len(vocab_fr))
# Out:
# 264 264

# %%
filenames = ['December', 'February', 'January', 'October', 'September']
path = './dataset/dataset/'

vocab_en = []
vocab_fr = []
for filename in filenames:
    doc_en = Document(f"{path}{filename}_english_2020.docx")
    doc_fr = Document(f"{path}{filename}_french_2020.docx")
    
    vocab_en += process_doc(doc_en)
    vocab_fr += process_doc(doc_fr)

raw_data = {"eng": vocab_en, "fre": vocab_fr}
df = pd.DataFrame(raw_data, columns=['eng', 'fre'])
df.to_csv('./dataset/ror_data.csv', index=False)
df.head()
# Out:
#                                                  eng  \
# 0                   the new heaven and the new earth
# 1  for what shall it profit a man, if he shall ga...
# 2  w for what shall it profit a man, if he shall ...
# 3  this is how you should view this current world...
# 4  the 23rd and 25th verses take it even further:...
#
#                                                  fre
# 0               le nouveau ciel et la nouvelle terre
# 1  et que sert-il à un homme de gagner tout le mo...
# 2  lorsqu’on fait la publicité d’un nouveau produ...
# 3  c’est ainsi que vous devriez voir le monde act...
# 4  les versets 23 et 25 vont plus en profondeur: ...

# %%
bible_data = pd.read_csv("./dataset/eng-fre-bible.csv")

# %%
bible_data["eng"] = bible_data['eng'].apply(str)
bible_data["fre"] = bible_data['fre'].apply(str)
bible_data.head()
# Out:
#                                                  eng  \
# 0  Genesis 1:1  In the beginning God created the ...
# 1  Genesis 1:2  And the earth was without form, a...
# 2  Genesis 1:3  And God said, Let there be light:...
# 3  Genesis 1:4  And God saw the light, that [it w...
# 4  Genesis 1:5  And God called the light Day, and...
#
#                                                  fre
# 0   Genèse 1:1  Au commencement Dieu créa les cie...
# 1   Genèse 1:2  Et la terre était désolation et v...
# 2   Genèse 1:3  Et Dieu dit: Que la lumière soit!...
# 3   Genèse 1:4  Et Dieu vit la lumière, qu'elle é...
# 4   Genèse 1:5  Et Dieu appela la lumière Jour; e...

# %%
bible_data = bible_data.append(df)

# %%
bible_data.tail()
# Out:
#                                                     eng  \
# 1379  when jesus heard the words of the centurion, t...
# 1380  what’s your desire? in which area do you requi...
# 1381  even now, act on his word. he said in john 14:...
# 1382  dear father, thank you for your precious word ...
# 1383     romans 10:17; 2 corinthians 4:13; hebrews 11:6
#
#                                                     fre
# 1379  quand jésus a entendu les paroles du centurion...
# 1380  quel est votre désir? dans quel domaine avezvo...
# 1381  même à l’instant, agissez selon sa parole. il ...
# 1382  cher père, merci pour ta précieuse parole qui ...
# 1383    romains 10:17; 2 corinthiens 4:13; hébreux 11:6

# %%
gen_data = pd.read_csv("./dataset/train.csv")

# %%
gen_data = gen_data[:15000]

# %%
gen_data.head()
# Out:
#                                              English  \
# 0  It does not bode at all well for Nigeria, at a...
# 1              But these are two parallel exercises.
# 2                        They are post-mortem tests.
# 3  In addition, it would highlight the need for t...
# 4  Just as important, however, is the need to saf...
#
#                                               French
# 0  Cela n'augure rien de bon pour le Nigeria, alo...
# 1       Mais il s'agit de deux exercices parallèles.
# 2                    Il s'agit de tests post mortem.
# 3  En outre, elle souligne la nécessité de placer...
# 4  Toutefois, la nécessité de garantir les servic...

# %%
gen_data = gen_data.rename(columns={"English": "eng", "French": "fre"}, inplace=False)

# %%
gen_data["eng"] = gen_data['eng'].apply(str)
gen_data["fre"] = gen_data['fre'].apply(str)
gen_data.tail()
# Out:
#                                                      eng  \
# 14995  Active Euro-Mediterranean institutions have be...
# 14996  Mr President, my Group firmly supports this re...
# 14997  We need a much deeper discussion around this p...
# 14998  This problem rarely affects small or medium-si...
# 14999  We are only a few weeks away from the Cancun c...
#
#                                                      fre
# 14995  Des institutions euro-méditerranéennes actives...
# 14996  Monsieur le Président, notre groupe soutient r...
# 14997  In faut une discussion bien plus approfondie s...
# 14998  Ce problème concerne rarement les petites et m...
# 14999  Quelques semaines nous séparent de la conféren...

# %%
bible_data = bible_data.append(gen_data)
bible_data.head()
# Out:
#                                                  eng  \
# 0  Genesis 1:1  In the beginning God created the ...
# 1  Genesis 1:2  And the earth was without form, a...
# 2  Genesis 1:3  And God said, Let there be light:...
# 3  Genesis 1:4  And God saw the light, that [it w...
# 4  Genesis 1:5  And God called the light Day, and...
#
#                                                  fre
# 0   Genèse 1:1  Au commencement Dieu créa les cie...
# 1   Genèse 1:2  Et la terre était désolation et v...
# 2   Genèse 1:3  Et Dieu dit: Que la lumière soit!...
# 3   Genèse 1:4  Et Dieu vit la lumière, qu'elle é...
# 4   Genèse 1:5  Et Dieu appela la lumière Jour; e...

# %%
test_data = pd.read_csv("./dataset/train.csv")
test_data = test_data[20000:25000]

test_data = test_data.rename(columns={"English": "eng", "French": "fre"}, inplace=False)

test_data["eng"] = test_data['eng'].apply(str)
test_data["fre"] = test_data['fre'].apply(str)

test_data.head()
# Out:
#                                                      eng  \
# 20000  Take for instance this year, which was an extr...
# 20001  I must point out that we are proceeding to vot...
# 20002  The object of this is to enable us to eventual...
# 20003  rapporteur. - Mr President, I really do not kn...
# 20004  Integrated pollution prevention and control: i...
#
#                                                      fre
# 20000  Prenons l'exemple de cette année, qui a été ex...
# 20001  Je vous signale que nous procédons à des votes...
# 20002  En fin de compte, cette procédure a pour but d...
# 20003  rapporteur. - Monsieur le Président, je ne sai...
# 20004  Émissions industrielles (prévention et réducti...

# %%
bible_data.to_csv("./final_data/eng_fre_train.csv")
bible_data.to_json("./final_data/eng_fre_train.json", orient='records', lines=True)

test_data.to_csv("./final_data/eng_fre_test.csv")
test_data.to_json("./final_data/eng_fre_test.json", orient='records', lines=True)

# %%
valid_data = pd.read_csv("./dataset/valid.csv")
valid_data = valid_data[:5000]

valid_data = valid_data.rename(columns={"English": "eng", "French": "fre"}, inplace=False)

valid_data["eng"] = valid_data['eng'].apply(str)
valid_data["fre"] = valid_data['fre'].apply(str)

valid_data.to_csv("./final_data/eng_fre_valid.csv")
valid_data.to_json("./final_data/eng_fre_valid.json", orient='records', lines=True)

# %%
df = pd.read_csv("./final_data/eng_fre_test.csv")
df[:10]
# Out:
#    Unnamed: 0                                                eng  \
# 0       20000  Take for instance this year, which was an extr...
# 1       20001  I must point out that we are proceeding to vot...
# 2       20002  The object of this is to enable us to eventual...
# 3       20003  rapporteur. - Mr President, I really do not kn...
# 4       20004  Integrated pollution prevention and control: i...
# 5       20005  Firstly, as a European Union, we should remain...
# 6       20006  The safety of Christians living in Turkey and ...
# 7       20007  Prior authorisation is the reason patients wen...
# 8       20008  Hell on earth is the description of how Europe...
# 9       20009  The question of setting MRLs for certain bioci...
#
#                                                  fre
# 0  Prenons l'exemple de cette année, qui a été ex...
# 1  Je vous signale que nous procédons à des votes...
# 2  En fin de compte, cette procédure a pour but d...
# 3  rapporteur. - Monsieur le Président, je ne sai...
# 4  Émissions industrielles (prévention et réducti...
# 5  En tant qu'Union européenne, nous devons reste...
# 6  La sécurité des chrétiens qui vivent en Turqui...
# 7  L'autorisation préalable, c'est ce qui a pouss...
# 8  L'enfer sur terre décrit parfaitement les épre...
# 9  On s'est également mis d'accord sur la questio...
